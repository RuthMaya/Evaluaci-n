# %% [markdown]
# <a href="https://colab.research.google.com/github/RuthMaya/Evaluaci-n/blob/main/MEX_ACTIVIDAD_5_(Evaluaci%C3%B3n)_PARTE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ACTIVIDAD 5 (Evaluación) PARTE 2**
# ## **Ruth Maya López**
# ## **A01707467**

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **MEX**

# %%
mex = pd.read_csv("Datos_limpios_MEX.csv", low_memory=False)

# %%
mex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17517 entries, 0 to 17516
# Data columns (total 72 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    17515 non-null  float64
#  1   id                                            17517 non-null  object
#  2   scrape_id                                     17517 non-null  object
#  3   host_id                                       17517 non-null  object
#  4   host_listings_count                           17517 non-null  object
#  5   host_total_listings_count                     17517 non-null  object
#  6   latitude                                      17517 non-null  object
#  7   longitude                                     17517 non-null  object
#  8   accommodates                                  17517 non-null  object
# ...

# %% [markdown]
# ### **a) host_acceptance_rate> 50%**

# %%
filtroa=mex[mex['host_acceptance_rate'] > 50]
filtroa
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 1             1.0      2072354  2.02303E+13   16840050                   3
# 2             2.0       696037  2.02303E+13    3531879                   4
# 3             3.0        35797  2.02303E+13     153786                   1
# 4             4.0        44616  2.02303E+13     196253                  16
# ...           ...          ...          ...        ...                 ...
# 17512     17510.0  6.55749E+17  2.02303E+13   10764020                 5.3
# 17513     17511.0  6.53905E+17  2.02303E+13  460400195                   1
# 17514     17512.0  6.53997E+17  2.02303E+13  257853661                  15
# 17515     17513.0  6.55753E+17  2.02303E+13   23021265                  13
# 17516     17514.0  6.54191E+17  2.02303E+13   22442781                   1
#
# ...

# %%
#Corroborar el filtro
filtroa['host_acceptance_rate'].unique()
# Out:
# array([ 90.,  86.,  70.,  95., 100.,  58.,  98.,  73.,  87.,  99.,  77.,
#         75.,  97.,  94.,  81.,  89.,  60.,  91.,  92.,  85.,  93.,  71.,
#         88.,  82.,  64.,  74.,  63.,  67.,  96.,  83.,  80.,  59.,  68.,
#         76.,  65.,  66.,  69.,  54.,  78.,  84.,  56.,  53.,  79.,  52.,
#         57.,  72.,  61.,  62.,  55.])

# %%
filtroa.to_csv("filtroa_MEX.csv")
from google.colab import files 
files.download("filtroa_MEX.csv")

# %% [markdown]
# ### **b) Sólo los registros con categoría “superhost”**

# %%
#Filtro por objeto 
filtrob=mex[mex["host_is_superhost"] == "t"]
filtrob
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 2             2.0       696037  2.02303E+13    3531879                   4
# 6             6.0        56074  2.02303E+13     265650                   2
# 7             7.0        61792  2.02303E+13     299558                   2
# 8             8.0       704779  2.02303E+13    2872228                  13
# 9             9.0       728372  2.02303E+13    3777702                   6
# ...           ...          ...          ...        ...                 ...
# 17507     17505.0  6.53875E+17  2.02303E+13  104953556                 5.3
# 17510     17508.0  6.51284E+17  2.02303E+13  403848214                 5.3
# 17511     17509.0  6.51307E+17  2.02303E+13  453255461                  10
# 17512     17510.0  6.55749E+17  2.02303E+13   10764020                 5.3
# 17513     17511.0  6.53905E+17  2.02303E+13  460400195                   1
#
# ...

# %%
#Corroborar el filtro
filtrob['host_is_superhost'].unique()
# Out:
# array(['t'], dtype=object)

# %%
filtrob.to_csv("filtrob_MEX.csv")
from google.colab import files 
files.download("filtrob_MEX.csv")

# %% [markdown]
# ### **c) Los registros que no hallan verificado identidad “ not identity_verified”**

# %%
#Filtro por objeto 
filtroc=mex[mex["host_identity_verified"] == "f"]
filtroc
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 21           21.0       131610  2.02303E+13     647454                   3
# 61           61.0       276504  2.02303E+13    1444589                   1
# 68           68.0       291804  2.02303E+13    1511568                   1
# 70           70.0       298873  2.02303E+13    1539548                   1
# ...           ...          ...          ...        ...                 ...
# 17349     17347.0  6.44149E+17  2.02303E+13  228573278                   1
# 17358     17356.0  6.44199E+17  2.02303E+13  102944480                   1
# 17377     17375.0  6.47862E+17  2.02303E+13  463917774                   1
# 17482     17480.0  6.50716E+17  2.02303E+13  462574140                   1
# 17491     17489.0  6.53782E+17  2.02303E+13  452016962                   1
#
# ...

# %%
#Corroborar el filtro
filtroc['host_identity_verified'].unique()
# Out:
# array(['f'], dtype=object)

# %%
filtroc.to_csv("filtroc_MEX.csv")
from google.colab import files 
files.download("filtroc_MEX.csv")

# %% [markdown]
# ### **d) Los registro cuyo property_type = “Private room” y “Hotel room”**

# %%
mex["property_type"].unique()
# Out:
# array(['Entire loft', 'Entire guest suite', 'Entire rental unit',
#        'Entire villa', 'Entire home', 'Entire condo',
#        'Private room in home', 'Room in serviced apartment',
#        'Entire serviced apartment', 'Private room in rental unit',
#        'Private room', 'Tiny home', 'Private room in townhouse',
#        'Private room in condo', 'Private room in guest suite',
#        'Private room in bed and breakfast', 'Entire guesthouse',
#        'Private room in guesthouse', 'Private room in serviced apartment',
#        'Shared room in rental unit', 'Room in boutique hotel',
#        'Entire bungalow', 'Casa particular', 'Private room in tiny home',
#        'Private room in loft', 'Entire townhouse', 'Shared room in condo',
#        'Shared room in home', 'Shared room in guesthouse',
#        'Room in bed and breakfast', 'Entire cabin',
#        'Shared room in hostel', 'Private room in farm stay',
#        'Private room in floor', 'Shared room in guest suite',
# ...

# %%
filtrod=mex[(mex["property_type"] == 'Private room') | (mex["property_type"] == "Hotel room")]
filtrod
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 21           21.0       131610  2.02303E+13     647454                   3
# 1062       1062.0     12271259  2.02303E+13    2556582                   1
# 2670       2670.0     19639981  2.02303E+13  136125882                   1
# 2805       2805.0     20089283  2.02303E+13  142841816                   1
# 3065       3065.0     21067896  2.02303E+13  151816281                   2
# 3257       3257.0     21765818  2.02303E+13  158580118                   1
# 3359       3359.0     22230184  2.02303E+13   93911392                  28
# 3372       3372.0     22247072  2.02303E+13   93911392                  28
# 3455       3455.0     22340146  2.02303E+13  115584349                   3
# 3571       3571.0     23026367  2.02303E+13  170856978                   1
# 3605       3605.0     23100799  2.02303E+13  103716258                   1
# ...

# %%
#Corroborar el filtro
filtrod['property_type'].unique()
# Out:
# array(['Private room'], dtype=object)

# %%
filtrod.to_csv("filtrod_MEX.csv")
from google.colab import files 
files.download("filtrod_MEX.csv")

# %% [markdown]
# ### **e) Los registros que cuenten con bathroom > 1**

# %%
mex['bathrooms_text'].unique()
# Out:
# array(['1.5 baths', '1 bath', '2 baths', '5.5 baths', '1 shared bath',
#        '1 private bath', '3 baths', '5 baths', '1.5 shared baths',
#        '2.5 baths', '4.5 baths', '6 baths', '3.5 baths', '2 shared baths',
#        '3 shared baths', '2.5 shared baths', 'Half-bath',
#        '8 shared baths', '4 shared baths', '4 baths', '10 baths',
#        '16 baths', '3.5 shared baths', '5 shared baths', '7 baths',
#        '20 baths', '4.5 shared baths', '0 shared baths', '0 baths',
#        '50 baths', '10 shared baths', '8.5 baths', '9 baths', '7.5 baths',
#        '11.5 baths', '8 baths', 'Shared half-bath', '14 baths',
#        '6 shared baths', '11 baths', '6.5 baths', nan, '15 baths',
#        '13 baths', 'Private half-bath', '15 shared baths',
#        '12 shared baths', '9.5 baths'], dtype=object)

# %%
filtroe=mex[~(mex["bathrooms_text"] == '1 bath')  & ~(mex["bathrooms_text"] == "1 private bath")]
filtroe
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 2             2.0       696037  2.02303E+13    3531879                   4
# 4             4.0        44616  2.02303E+13     196253                  16
# 5             5.0      2075738  2.02303E+13    2339771                   1
# 7             7.0        61792  2.02303E+13     299558                   2
# ...           ...          ...          ...        ...                 ...
# 17507     17505.0  6.53875E+17  2.02303E+13  104953556                 5.3
# 17508     17506.0  6.49715E+17  2.02303E+13  254403121                   1
# 17509     17507.0  6.53891E+17  2.02303E+13   87539949                  12
# 17510     17508.0  6.51284E+17  2.02303E+13  403848214                 5.3
# 17515     17513.0  6.55753E+17  2.02303E+13   23021265                  13
#
# ...

# %%
#Corroborar el filtro
filtroe['bathrooms_text'].unique()
# Out:
# array(['1.5 baths', '2 baths', '5.5 baths', '1 shared bath', '3 baths',
#        '5 baths', '1.5 shared baths', '2.5 baths', '4.5 baths', '6 baths',
#        '3.5 baths', '2 shared baths', '3 shared baths',
#        '2.5 shared baths', 'Half-bath', '8 shared baths',
#        '4 shared baths', '4 baths', '10 baths', '16 baths',
#        '3.5 shared baths', '5 shared baths', '7 baths', '20 baths',
#        '4.5 shared baths', '0 shared baths', '0 baths', '50 baths',
#        '10 shared baths', '8.5 baths', '9 baths', '7.5 baths',
#        '11.5 baths', '8 baths', 'Shared half-bath', '14 baths',
#        '6 shared baths', '11 baths', '6.5 baths', nan, '15 baths',
#        '13 baths', 'Private half-bath', '15 shared baths',
#        '12 shared baths', '9.5 baths'], dtype=object)

# %%
filtroe.to_csv("filtroe_MEX.csv")
from google.colab import files 
files.download("filtroe_MEX.csv")

# %% [markdown]
# ### **f) Los registros cuyo precio sea mayor de $10,000 y que sean de tipo “Entire home”**

# %%
filtrof = mex[(mex["price"] > 10000) & (mex["room_type"] == "Entire home/apt")]
filtrof
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 4             4.0        44616  2.02303E+13     196253                  16
# 37           37.0       187030  2.02303E+13     899360                   6
# 418         418.0      6041044  2.02303E+13    7529413                   1
# 544         544.0      6871835  2.02303E+13   36014559                   1
# 958         958.0      9946549  2.02303E+13   51117526                   1
# ...           ...          ...          ...        ...                 ...
# 16927     16925.0  6.30419E+17  2.02303E+13  459926071                   1
# 16966     16964.0  6.28233E+17  2.02303E+13  418651325                 5.3
# 17010     17008.0  6.34356E+17  2.02303E+13  460826213                   1
# 17034     17032.0  6.34789E+17  2.02303E+13  418651325                 5.3
# 17121     17119.0   6.2976E+17  2.02303E+13  418651325                 5.3
#
# ...

# %%
filtrof.to_csv("filtrof_MEX.csv")
from google.colab import files 
files.download("filtrof_MEX.csv")

# %% [markdown]
# ### **g) Los registros cuyo review_scores_cleanliness > 4.5**

# %%
filtrog = mex[mex['review_scores_cleanliness'] > 4.5]
filtrog
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 1             1.0      2072354  2.02303E+13   16840050                   3
# 2             2.0       696037  2.02303E+13    3531879                   4
# 3             3.0        35797  2.02303E+13     153786                   1
# 4             4.0        44616  2.02303E+13     196253                  16
# ...           ...          ...          ...        ...                 ...
# 17512     17510.0  6.55749E+17  2.02303E+13   10764020                 5.3
# 17513     17511.0  6.53905E+17  2.02303E+13  460400195                   1
# 17514     17512.0  6.53997E+17  2.02303E+13  257853661                  15
# 17515     17513.0  6.55753E+17  2.02303E+13   23021265                  13
# 17516     17514.0  6.54191E+17  2.02303E+13   22442781                   1
#
# ...

# %%
#Corroborar el filtro
filtrog['review_scores_cleanliness'].unique()
# Out:
# array([4.95, 4.88, 4.71, 4.7 , 4.9 , 4.75, 4.69, 4.96, 4.73, 4.83, 4.8 ,
#        4.6 , 5.  , 4.84, 4.91, 4.67, 4.78, 4.92, 4.86, 4.97, 4.59, 4.93,
#        4.63, 4.68, 4.65, 4.58, 4.81, 4.72, 4.85, 4.94, 4.89, 4.76, 4.56,
#        4.87, 4.82, 4.51, 4.62, 4.77, 4.79, 4.74, 4.66, 4.99, 4.54, 4.98,
#        4.57, 4.55, 4.64, 4.61, 4.52, 4.53])

# %%
filtrog.to_csv("filtrog_MEX.csv")
from google.colab import files 
files.download("filtrog_MEX.csv")

# %% [markdown]
# ### **h) Los registros cuyo review_scores_value > 4.9**

# %%
filtroh = mex[mex['review_scores_value'] > 4.9]
filtroh
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 10           10.0      2083241  2.02303E+13    8282570                   7
# 11           11.0        67703  2.02303E+13     334451                   3
# 13           13.0        70644  2.02303E+13     212109                   3
# 24           24.0       783080  2.02303E+13    1767559                   3
# 26           26.0      2118573  2.02303E+13   10802698                   3
# ...           ...          ...          ...        ...                 ...
# 17492     17490.0  6.53811E+17  2.02303E+13  202892955                   6
# 17498     17496.0  6.53834E+17  2.02303E+13  245618000                 5.3
# 17500     17498.0  6.50969E+17  2.02303E+13  309982168                   3
# 17501     17499.0  6.53854E+17  2.02303E+13  123526726                  26
# 17509     17507.0  6.53891E+17  2.02303E+13   87539949                  12
#
# ...

# %%
#Corroborar el filtro
filtroh['review_scores_value'].unique()
# Out:
# array([4.91, 4.92, 5.  , 4.95, 4.98, 4.94, 4.97, 4.96, 4.93, 4.99])

# %%
filtroh.to_csv("filtroh_MEX.csv")
from google.colab import files 
files.download("filtroh_MEX.csv")

# %% [markdown]
# ### **i) Los registros cuya availability_365< 100**

# %%
mex.availability_365 = mex.availability_365.replace({'f':'0'}, regex=False)

# %%
mex.availability_365 = mex.availability_365.astype(int)

# %%
filtroi=mex[mex['availability_365'] < 100]
filtroi
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 2             2.0       696037  2.02303E+13    3531879                   4
# 21           21.0       131610  2.02303E+13     647454                   3
# 26           26.0      2118573  2.02303E+13   10802698                   3
# 37           37.0       187030  2.02303E+13     899360                   6
# 38           38.0       187745  2.02303E+13     899360                   6
# ...           ...          ...          ...        ...                 ...
# 17451     17449.0  6.53539E+17  2.02303E+13  462374848                   5
# 17467     17465.0  6.53614E+17  2.02303E+13  462374848                   5
# 17471     17469.0  6.50698E+17  2.02303E+13  335634100                   1
# 17472     17470.0  6.49328E+17  2.02303E+13  115584349                   3
# 17509     17507.0  6.53891E+17  2.02303E+13   87539949                  12
#
# ...

# %%
#Corroborar el filtro
filtroi['availability_365'].unique()
# Out:
# array([87, 88,  0, 26, 90, 80,  2, 72, 30, 11, 48, 84, 16, 62, 81, 75, 51,
#        74, 58, 71, 50, 54, 57, 79, 56, 77, 49, 89, 73, 52, 15, 17, 85, 37,
#        61, 83, 63, 32,  3,  1, 33,  8, 70,  6, 40, 39, 23, 53, 18, 27, 86,
#        55, 82, 14, 20, 43, 25, 99, 60, 47, 44, 46, 66, 65, 35, 69, 59, 76,
#        78, 93, 34, 28, 64, 41,  5, 67, 19, 92, 10, 98, 31,  9, 94, 45, 13,
#        24, 22, 21, 29, 36, 91, 42, 38, 12,  4, 97, 96,  7, 68, 95])

# %%
filtroi.to_csv("filtroi_MEX.csv")
from google.colab import files 
files.download("filtroi_MEX.csv")

# %% [markdown]
# ### **j) Los registros cuya host_response_time sea “within an hour”**

# %%
filtroj = mex[mex["host_response_time"] == "within an hour"]
filtroj
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 2             2.0       696037  2.02303E+13    3531879                   4
# 3             3.0        35797  2.02303E+13     153786                   1
# 4             4.0        44616  2.02303E+13     196253                  16
# 6             6.0        56074  2.02303E+13     265650                   2
# 7             7.0        61792  2.02303E+13     299558                   2
# ...           ...          ...          ...        ...                 ...
# 17510     17508.0  6.51284E+17  2.02303E+13  403848214                 5.3
# 17512     17510.0  6.55749E+17  2.02303E+13   10764020                 5.3
# 17513     17511.0  6.53905E+17  2.02303E+13  460400195                   1
# 17514     17512.0  6.53997E+17  2.02303E+13  257853661                  15
# 17515     17513.0  6.55753E+17  2.02303E+13   23021265                  13
#
# ...

# %%
#Corroborar el filtro
filtroj['host_response_time'].unique()
# Out:
# array(['within an hour'], dtype=object)

# %%
filtroj.to_csv("filtroj_MEX.csv")
from google.colab import files 
files.download("filtroj_MEX.csv")
