# %% [markdown]
# <a href="https://colab.research.google.com/github/RuthMaya/Evaluaci-n/blob/main/EUA_ACTIVIDAD_5_(Evaluaci%C3%B3n)_PARTE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ACTIVIDAD 5 (Evaluación) PARTE 2**
# ## **Ruth Maya López**
# ## **A01707467**

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **EUA**

# %%
eua = pd.read_csv("Datos_limpios_EUA.csv", encoding= 'unicode_escape')

# %%
eua.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6936 entries, 0 to 6935
# Data columns (total 73 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host                                          6936 non-null   int64
#  1   Ã¯Â»Â¿id                                      6936 non-null   float64
#  2   scrape_id                                     6936 non-null   float64
#  3   host_id                                       6936 non-null   float64
#  4   host_listings_count                           6936 non-null   float64
#  5   host_total_listings_count                     6936 non-null   float64
#  6   latitude                                      6936 non-null   float64
#  7   longitude                                     6936 non-null   float64
#  8   accommodates                                  6936 non-null   int64
# ...

# %% [markdown]
# ### **a) host_acceptance_rate> 50%**

# %%
filtroa=eua[eua['host_acceptance_rate'] > 50]
filtroa
# Out:
#       host    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 0        0       958.0  2.020000e+13       1169.0                  1.0
# 1        1      5858.0  2.020000e+13       8904.0                  2.0
# 2        2      8142.0  2.020000e+13      21994.0                 13.0
# 4        4      8739.0  2.020000e+13       7149.0                  2.0
# 5        5    142177.0  2.020000e+13     656263.0                  1.0
# ...    ...         ...           ...          ...                  ...
# 6929  6929  27790615.3  2.020000e+13  226555948.0                  5.3
# 6930  6930  27790615.3  2.020000e+13  286802480.0                  6.0
# 6931  6931  27790615.3  2.020000e+13   87507815.4                  9.0
# 6932  6932  27790615.3  2.020000e+13   87507815.4                  1.0
# 6933  6933  27790615.3  2.020000e+13   87507815.4                  1.0
#
#       host_total_listings_count   latitude   longitude  accommodates  \
# ...

# %%
#Corroborar el filtro
filtroa['host_acceptance_rate'].unique()
# Out:
# array([100,  71,  73,  90,  95,  67,  61,  84,  82,  91,  80,  93,  94,
#         96,  60,  83,  87,  99,  89,  62,  75,  98,  85,  97,  92,  55,
#         69,  88,  86,  77,  76,  66,  81,  72,  79,  58,  63,  54,  74,
#         78,  56,  59,  70,  57,  64,  53,  52,  65,  68])

# %%
filtroa.to_csv("filtroa_EUA.csv")
from google.colab import files 
files.download("filtroa_EUA.csv")

# %% [markdown]
# ### **b) Sólo los registros con categoría “superhost”**

# %%
#Filtro por objeto 
filtrob=eua[eua["host_is_superhost"] == "t"]
filtrob
# Out:
#       host    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 0        0       958.0  2.020000e+13       1169.0                  1.0
# 4        4      8739.0  2.020000e+13       7149.0                  2.0
# 7        7     10537.0  2.020000e+13      36752.0                  2.0
# 8        8    491867.0  2.020000e+13     969518.0                  2.0
# 9        9    144242.0  2.020000e+13     699215.0                  2.0
# ...    ...         ...           ...          ...                  ...
# 6913  6913  27790615.3  2.020000e+13   36046172.0                  2.0
# 6918  6918  27790615.3  2.020000e+13  375566645.0                 23.0
# 6919  6919  27790615.3  2.020000e+13     330231.0                 10.0
# 6923  6923  27790615.3  2.020000e+13    4452428.0                  3.0
# 6929  6929  27790615.3  2.020000e+13  226555948.0                  5.3
#
#       host_total_listings_count   latitude   longitude  accommodates  \
# ...

# %%
#Corroborar el filtro
filtrob['host_is_superhost'].unique()
# Out:
# array(['t'], dtype=object)

# %%
filtrob.to_csv("filtrob_EUA.csv")
from google.colab import files 
files.download("filtrob_EUA.csv")

# %% [markdown]
# ### **c) Los registros que no hallan verificado identidad “ not identity_verified”**

# %%
#Filtro por objeto 
filtroc=eua[eua["host_identity_verified"] == "f"]
filtroc
# Out:
#       host    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 6        6    490931.0  2.020000e+13    1269188.0                  1.0
# 28      28     18231.0  2.020000e+13      70224.0                  1.0
# 38      38    193292.0  2.020000e+13     937281.0                  1.0
# 39      39    201313.0  2.020000e+13     984585.0                  1.0
# 71      71    231129.0  2.020000e+13    1208533.0                  5.0
# ...    ...         ...           ...          ...                  ...
# 6885  6885  27790615.3  2.020000e+13  157999191.0                 24.0
# 6905  6905  27790615.3  2.020000e+13  240202942.0                  2.0
# 6931  6931  27790615.3  2.020000e+13   87507815.4                  9.0
# 6932  6932  27790615.3  2.020000e+13   87507815.4                  1.0
# 6933  6933  27790615.3  2.020000e+13   87507815.4                  1.0
#
#       host_total_listings_count   latitude   longitude  accommodates  \
# ...

# %%
#Corroborar el filtro
filtroc['host_identity_verified'].unique()
# Out:
# array(['f'], dtype=object)

# %%
filtroc.to_csv("filtroc_EUA.csv")
from google.colab import files 
files.download("filtroc_EUA.csv")

# %% [markdown]
# ### **d) Los registro cuyo property_type = “Private room” y “Hotel room”**

# %%
eua["property_type"].unique()
# Out:
# array(['Entire serviced apartment', 'Entire rental unit',
#        'Private room in rental unit', 'Entire condo',
#        'Private room in condo', 'Private room', 'Entire home',
#        'Entire guest suite', 'Entire guesthouse', 'Private room in home',
#        'Entire loft', 'Entire townhouse', 'Private room in guest suite',
#        'Private room in cottage', 'Private room in townhouse',
#        'Private room in hostel', 'Private room in bungalow',
#        'Shared room in loft', 'Shared room in rental unit',
#        'Room in hotel', 'Room in boutique hotel', 'Entire cottage',
#        'Private room in bed and breakfast',
#        'Shared room in bed and breakfast', 'Entire vacation home',
#        'Private room in loft', 'Room in serviced apartment',
#        'Entire bungalow', 'Shared room in home', 'Floor',
#        'Private room in villa', 'Entire place', 'Entire resort',
#        'Shared room in hostel', 'Room in aparthotel',
# ...

# %%
filtrod=eua[(eua["property_type"] == 'Private room') | (eua["property_type"] == "Hotel room")]
filtrod
# Out:
#       host    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 7        7     10537.0  2.020000e+13      36752.0                  2.0
# 1575  1575  14305759.0  2.020000e+13   29483318.0                  3.0
# 2049  2049  20957462.0  2.020000e+13  150732464.0                  7.0
# 4014  4014  43477461.0  2.020000e+13  150732464.0                  7.0
#
#       host_total_listings_count  latitude  longitude  accommodates  bedrooms  \
# 7                           3.0  37.71750 -122.39698             2       1.0
# 1575                        3.0  37.75145 -122.40719             2       1.0
# 2049                        9.0  37.79586 -122.41915             2       1.6
# 4014                        9.0  37.79525 -122.41931             1       1.6
#
#       ...     room_type    bathrooms_text  \
# 7     ...  Private room  1.5 shared baths
# 1575  ...  Private room     1 shared bath
# 2049  ...  Private room    1 private bath
# 4014  ...  Private room            1 bath
#
# ...

# %%
#Corroborar el filtro
filtrod['property_type'].unique()
# Out:
# array(['Private room'], dtype=object)

# %%
filtrod.to_csv("filtrod_EUA.csv")
from google.colab import files 
files.download("filtrod_EUA.csv")

# %% [markdown]
# ### **e) Los registros que cuenten con bathroom > 1**

# %%
eua['bathrooms_text'].unique()
# Out:
# array(['1 bath', '4 shared baths', '1.5 baths', '1 private bath',
#        '1.5 shared baths', '2 baths', '3 shared baths', 'Half-bath',
#        '2 shared baths', '2.5 baths', '3 baths', '1 shared bath',
#        '3.5 baths', 'Shared half-bath', '0 shared baths',
#        'Private half-bath', '0 baths', '10 shared baths', '10 baths',
#        '4.5 baths', '4 baths', '2.5 shared baths', '5 shared baths',
#        '8 shared baths', '6 shared baths', '3.5 shared baths', '5 baths',
#        '6.5 shared baths', '5.5 baths', '6.5 baths', '8.5 baths',
#        '6 baths'], dtype=object)

# %%
filtroe=eua[~(eua["bathrooms_text"] == '1 bath')  & ~(eua["bathrooms_text"] == "1 private bath")]
filtroe
# Out:
#       host    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 2        2      8142.0  2.020000e+13      21994.0                 13.0
# 3        3      8339.0  2.020000e+13      24215.0                  2.0
# 7        7     10537.0  2.020000e+13      36752.0                  2.0
# 8        8    491867.0  2.020000e+13     969518.0                  2.0
# 9        9    144242.0  2.020000e+13     699215.0                  2.0
# ...    ...         ...           ...          ...                  ...
# 6926  6926  27790615.3  2.020000e+13  222540569.0                  7.0
# 6929  6929  27790615.3  2.020000e+13  226555948.0                  5.3
# 6930  6930  27790615.3  2.020000e+13  286802480.0                  6.0
# 6933  6933  27790615.3  2.020000e+13   87507815.4                  1.0
# 6934  6934  27790615.3  2.020000e+13   87507815.4                  3.0
#
#       host_total_listings_count   latitude   longitude  accommodates  \
# ...

# %%
#Corroborar el filtro
filtroe['bathrooms_text'].unique()
# Out:
# array(['4 shared baths', '1.5 baths', '1.5 shared baths', '2 baths',
#        '3 shared baths', 'Half-bath', '2 shared baths', '2.5 baths',
#        '3 baths', '1 shared bath', '3.5 baths', 'Shared half-bath',
#        '0 shared baths', 'Private half-bath', '0 baths',
#        '10 shared baths', '10 baths', '4.5 baths', '4 baths',
#        '2.5 shared baths', '5 shared baths', '8 shared baths',
#        '6 shared baths', '3.5 shared baths', '5 baths',
#        '6.5 shared baths', '5.5 baths', '6.5 baths', '8.5 baths',
#        '6 baths'], dtype=object)

# %%
filtroe.to_csv("filtroe_EUA.csv")
from google.colab import files 
files.download("filtroe_EUA.csv")

# %% [markdown]
# ### **f) Los registros cuyo precio sea mayor de $10,000 y que sean de tipo “Entire home”**

# %%
filtrof = eua[(eua["price"] > 10000) & (eua["room_type"] == "Entire home/apt")]
filtrof
# Out:
#       host    Ã¯Â»Â¿id     scrape_id     host_id  host_listings_count  \
# 5759  5759  27790615.3  2.020000e+13  32878131.0                  3.0
# 6490  6490  27790615.3  2.020000e+13  91333416.0                 32.0
#
#       host_total_listings_count   latitude  longitude  accommodates  bedrooms  \
# 5759                        6.0  37.732590 -122.43337             4       1.0
# 6490                       50.0  37.781091 -122.47233             4       2.0
#
#       ...        room_type  bathrooms_text  \
# 5759  ...  Entire home/apt          1 bath
# 6490  ...  Entire home/apt          1 bath
#
#                                               amenities  price  \
# 5759  ["Carbon monoxide alarm", "Security cameras on...  14000
# 6490  ["Carbon monoxide alarm", "Hangers", "Iron", "...  25000
#
#       has_availability  calendar_last_scraped  first_review  last_review  \
# 5759                 t             06/03/2023    24/08/2022   15/11/2022
# ...

# %%
filtrof.to_csv("filtrof_EUA.csv")
from google.colab import files 
files.download("filtrof_EUA.csv")

# %% [markdown]
# ### **g) Los registros cuyo review_scores_cleanliness > 4.5**

# %%
filtrog = eua[eua['review_scores_cleanliness'] > 4.5]
filtrog
# Out:
#       host    Ã¯Â»Â¿id     scrape_id     host_id  host_listings_count  \
# 0        0       958.0  2.020000e+13      1169.0                  1.0
# 1        1      5858.0  2.020000e+13      8904.0                  2.0
# 2        2      8142.0  2.020000e+13     21994.0                 13.0
# 3        3      8339.0  2.020000e+13     24215.0                  2.0
# 4        4      8739.0  2.020000e+13      7149.0                  2.0
# ...    ...         ...           ...         ...                  ...
# 6931  6931  27790615.3  2.020000e+13  87507815.4                  9.0
# 6932  6932  27790615.3  2.020000e+13  87507815.4                  1.0
# 6933  6933  27790615.3  2.020000e+13  87507815.4                  1.0
# 6934  6934  27790615.3  2.020000e+13  87507815.4                  3.0
# 6935  6935  27790615.3  2.020000e+13   4836128.0                  2.0
#
#       host_total_listings_count   latitude   longitude  accommodates  \
# ...

# %%
#Corroborar el filtro
filtrog['review_scores_cleanliness'].unique()
# Out:
# array([4.92, 4.87, 4.9 , 5.  , 4.94, 4.88, 4.75, 4.86, 4.89, 4.69, 4.74,
#        4.64, 4.95, 4.65, 4.84, 4.82, 4.63, 4.85, 4.93, 4.76, 4.97, 4.71,
#        4.73, 4.66, 4.59, 4.83, 4.98, 4.51, 4.81, 4.8 , 4.53, 4.7 , 4.56,
#        4.91, 4.52, 4.62, 4.96, 4.78, 4.68, 4.79, 4.99, 4.61, 4.77, 4.57,
#        4.67, 4.6 , 4.55, 4.54, 4.58, 4.72])

# %%
filtrog.to_csv("filtrog_EUA.csv")
from google.colab import files 
files.download("filtrog_EUA.csv")

# %% [markdown]
# ### **h) Los registros cuyo review_scores_value > 4.9**

# %%
filtroh = eua[eua['review_scores_value'] > 4.9]
filtroh
# Out:
#       host    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 9        9    144242.0  2.020000e+13     699215.0                  2.0
# 24      24    149108.0  2.020000e+13     719538.0                  2.0
# 26      26     12522.0  2.020000e+13      18431.0                  1.0
# 46      46    530857.0  2.020000e+13    2607120.0                  2.0
# 53      53    561602.0  2.020000e+13    2760904.0                  1.0
# ...    ...         ...           ...          ...                  ...
# 6920  6920  27790615.3  2.020000e+13  407298390.0                  9.0
# 6924  6924  27790615.3  2.020000e+13  222540569.0                  7.0
# 6925  6925  27790615.3  2.020000e+13  222540569.0                  7.0
# 6927  6927  27790615.3  2.020000e+13   87507815.4                 32.0
# 6932  6932  27790615.3  2.020000e+13   87507815.4                  1.0
#
#       host_total_listings_count   latitude   longitude  accommodates  \
# ...

# %%
#Corroborar el filtro
filtroh['review_scores_value'].unique()
# Out:
# array([4.95, 5.  , 4.93, 4.91, 4.96, 4.94, 4.92, 4.97, 4.98])

# %%
filtroh.to_csv("filtroh_EUA.csv")
from google.colab import files 
files.download("filtroh_EUA.csv")

# %% [markdown]
# ### **i) Los registros cuya availability_365< 100**

# %%
filtroi=eua[eua['availability_365'] < 100]
filtroi
# Out:
#       host    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 5        5    142177.0  2.020000e+13     656263.0                  1.0
# 8        8    491867.0  2.020000e+13     969518.0                  2.0
# 9        9    144242.0  2.020000e+13     699215.0                  2.0
# 11      11    144978.0  2.020000e+13     216682.0                  9.0
# 15      15    501770.0  2.020000e+13    2475480.0                  5.0
# ...    ...         ...           ...          ...                  ...
# 6913  6913  27790615.3  2.020000e+13   36046172.0                  2.0
# 6917  6917  27790615.3  2.020000e+13   45555637.0                  1.0
# 6918  6918  27790615.3  2.020000e+13  375566645.0                 23.0
# 6923  6923  27790615.3  2.020000e+13    4452428.0                  3.0
# 6931  6931  27790615.3  2.020000e+13   87507815.4                  9.0
#
#       host_total_listings_count   latitude   longitude  accommodates  \
# ...

# %%
#Corroborar el filtro
filtroi['availability_365'].unique()
# Out:
# array([32,  7, 64, 55, 79, 89, 56, 88, 49, 87, 25, 29, 39,  3, 67, 95, 74,
#        91,  0, 38, 33, 60, 51, 62,  4, 58, 28, 80, 19, 30, 76, 59, 34, 93,
#        97, 46, 14, 10, 82, 57,  8, 73, 13, 36, 23, 37, 61, 68, 92, 71, 44,
#        90, 45, 83, 41, 42, 99, 65, 63, 35,  1, 22, 31,  9, 77, 70, 27, 86,
#        26, 75, 69, 24, 85, 43, 54, 66, 53, 40, 12, 96, 47, 16,  5, 17, 50,
#        18, 52, 21, 84, 81,  2, 78, 11, 48,  6, 20, 94, 72, 15, 98])

# %%
filtroi.to_csv("filtroi_EUA.csv")
from google.colab import files 
files.download("filtroi_EUA.csv")

# %% [markdown]
# ### **j) Los registros cuya host_response_time sea “within an hour”**

# %%
filtroj = eua[eua["host_response_time"] == "within an hour"]
filtroj
# Out:
#       host    Ã¯Â»Â¿id     scrape_id     host_id  host_listings_count  \
# 0        0       958.0  2.020000e+13      1169.0                  1.0
# 2        2      8142.0  2.020000e+13     21994.0                 13.0
# 4        4      8739.0  2.020000e+13      7149.0                  2.0
# 5        5    142177.0  2.020000e+13    656263.0                  1.0
# 12      12    493889.0  2.020000e+13   2439917.0                  2.0
# ...    ...         ...           ...         ...                  ...
# 6931  6931  27790615.3  2.020000e+13  87507815.4                  9.0
# 6932  6932  27790615.3  2.020000e+13  87507815.4                  1.0
# 6933  6933  27790615.3  2.020000e+13  87507815.4                  1.0
# 6934  6934  27790615.3  2.020000e+13  87507815.4                  3.0
# 6935  6935  27790615.3  2.020000e+13   4836128.0                  2.0
#
#       host_total_listings_count   latitude   longitude  accommodates  \
# ...

# %%
#Corroborar el filtro
filtroj['host_response_time'].unique()
# Out:
# array(['within an hour'], dtype=object)

# %%
filtroj.to_csv("filtroj_EUA.csv")
from google.colab import files 
files.download("filtroj_EUA.csv")
